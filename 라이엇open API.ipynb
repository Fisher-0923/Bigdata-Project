# %%
 api_key = "RGAPI-b12dbe86-4a30-4d2a-87d6-dc30d6a8801a"  # API 키

# %%
import requests
import pandas as pd
import time
import datetime
import os
import json

# %%
path = '/content/drive/MyDrive/롤 데이터 분석/meta_data'
print(f"경로 존재 여부: {os.path.exists(path)}")
# Out:
# 경로 존재 여부: True

# %%
def User_Per_Tier(tier, division):
    global cnt
    tier = tier

    # division 입력 문자로 치환
    if division == 1:
        division = 'I'
    elif division == 2:
        division = 'II'
    elif division == 3:
        division = 'III'
    elif division == 4:
        division = 'IV'
    else:
        print("잘못된 division 입력")
        return  # 잘못된 입력일 경우 함수를 종료

    # 데이터 저장을 위한 리스트 초기화
    globals()[tier + division] = []

    # 유저 수 카운트
    user_cnt = 0

    print(tier + ' ' + division + ' 수집 시작')

    # 조건 충족까지 반복
    while True:
        url = f'https://kr.api.riotgames.com/lol/league/v4/entries/RANKED_SOLO_5x5/{tier}/{division}?page={cnt}&api_key={api_key}'
        result = requests.get(url)

        # 상태 코드 확인
        if result.status_code != 200:
            print(f"API 요청 실패: {result.status_code} - {result.text}")
            break

        result = result.json()

        if not isinstance(result, list):
            print(f"Unexpected response format: {result}")
            break

        if len(result) == 0:
            print("데이터 없음")
            break

        for i in range(len(result)):
            try:
                wins = int(result[i]['wins'])
                losses = int(result[i]['losses'])
                games = wins + losses
                win_ratio = (wins / games) * 100  # 승률을 백분율로 계산

                # 200전 이상, 승률 55~45% 유저만 수집
                if games >= 80 and 40 <= win_ratio <= 65:
                    summoner_id = result[i]['summonerId']
                    league_points = result[i]['leaguePoints']
                    rank = result[i]['rank']

                    # 필요한 데이터만 수집
                    globals()[tier + division].append({
                        'summonerId': summoner_id,
                        'tier': tier,
                        'rank': rank,
                        'leaguePoints': league_points,
                        'wins': wins,
                        'losses': losses,
                        'winRatio': win_ratio
                    })

                    user_cnt += 1
                    if user_cnt % 100 == 0:
                        print(f"{user_cnt}/100")

            except KeyError as e:
                print(f"KeyError 발생: {e}, 데이터: {result[i]}")
                continue

        if cnt % 20 == 0:
            print(f"RIOT API 카운트 횟수: {cnt}")

        if cnt % 50 == 0:
            print("RIOT API 규정으로 인해 2분간 정지합니다.")
            now = datetime.datetime.now()
            print(f"현재 시간: {now.strftime('%H시 %M분 %S초')}")
            time.sleep(70)
            print("재개합니다.")

        if len(globals()[tier + division]) >= 100:
            to_df = pd.DataFrame(globals()[tier + division])
            os.makedirs('/content/drive/MyDrive/롤 데이터 분석/meta_data', exist_ok=True)
            to_df.to_csv(f'/content/drive/MyDrive/롤 데이터 분석/meta_data/{tier}_{division}.csv', index=False, encoding='cp949')
            print(f"파일 생성 완료: {tier}_{division}.csv")
            break

        cnt += 1

    # 수집된 데이터 개수 확인
    print(f"수집된 데이터 개수: {len(globals()[tier + division])}")

# 자동화
tier_list = ['BRONZE', 'SILVER', 'GOLD', 'PLATINUM', 'EMERALD', 'DIAMOND']
division_list = [1, 2, 3, 4]

cnt = 1
for tier in tier_list:
    for division in division_list:
        User_Per_Tier(tier, division)

# D:/Big Data Analysis/200 GAMES

# %%
base_url = "https://kr.api.riotgames.com"
max_retries = 5  # 최대 재시도 횟수

def get_puuid(summoner_id):
    url = f"{base_url}/lol/summoner/v4/summoners/{summoner_id}?api_key={api_key}"
    retries = 0
    while retries < max_retries:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            return data.get('puuid')
        elif response.status_code == 429:
            print(f"Rate limit exceeded for Summoner ID: {summoner_id}. Retrying after 2 minutes.")
            time.sleep(120)  # 2분 대기
        else:
            print(f"Error getting puuid for {summoner_id}: {response.status_code} - {response.text}")
            return None
        retries += 1
    print(f"Failed to get puuid for Summoner ID: {summoner_id} after {max_retries} retries.")
    return None

def add_puuid_to_csv(file_path):
    df = pd.read_csv(file_path, encoding='cp949')

    # 'puuid' 열 추가
    df['puuid'] = df['summonerId'].apply(lambda x: get_puuid(x))

    # 결과를 새로운 CSV 파일로 저장
    output_file = file_path.replace('.csv', '_with_puuid.csv')
    df.to_csv(output_file, index=False, encoding='cp949')
    print(f"파일 생성 완료: {output_file}")

def process_all_csv_files(path):
    for filename in os.listdir(path):
        if filename.endswith('.csv') and not filename.endswith('_with_puuid.csv'):
            csv_file = os.path.join(path, filename)
            print(f"처리 중: {csv_file}")
            add_puuid_to_csv(csv_file)

# 예시 실행
process_all_csv_files('/content/drive/MyDrive/롤 데이터 분석/meta_data')
# Out:
# 처리 중: D:/Big Data Analysis/200 GAMES/GOLD_II.csv
# 파일 생성 완료: D:/Big Data Analysis/200 GAMES/GOLD_II_with_puuid.csv
# 처리 중: D:/Big Data Analysis/200 GAMES/EMERALD_II.csv
# Rate limit exceeded for Summoner ID: V0l8MwmL6xoDQZ56zpLf07X_P2ovf9gfon5EpFnA7ISmbEI. Retrying after 2 minutes.
# Rate limit exceeded for Summoner ID: rwturVjduXPOiSB-K1PFfzYzExMa14ebcONjUDThXsfW6Z4. Retrying after 2 minutes.
# 파일 생성 완료: D:/Big Data Analysis/200 GAMES/EMERALD_II_with_puuid.csv
# 처리 중: D:/Big Data Analysis/200 GAMES/PLATINUM_I.csv
# Rate limit exceeded for Summoner ID: XxLBqMfdkBXH0ZR7xvYpLFZMW7d_FqyA8ncspCn1MNB-rLI. Retrying after 2 minutes.
# 파일 생성 완료: D:/Big Data Analysis/200 GAMES/PLATINUM_I_with_puuid.csv
# 처리 중: D:/Big Data Analysis/200 GAMES/GOLD_I.csv
# Rate limit exceeded for Summoner ID: LgJYiPSiy7TPbsfh6ZCyml3kHMv2cgdVPo9KQ2CPGJGv_7c. Retrying after 2 minutes.
# 파일 생성 완료: D:/Big Data Analysis/200 GAMES/GOLD_I_with_puuid.csv
# 처리 중: D:/Big Data Analysis/200 GAMES/BRONZE_IV.csv
# Rate limit exceeded for Summoner ID: 4p29KqTDys9_BARunfWyu50ryDyowCTibmuiG1z3P4PfwcKO. Retrying after 2 minutes.
# Rate limit exceeded for Summoner ID: sfSQzbbklKkTF0mZioBrGNX5jsLM5hdmmZ45nNi4jAPdYa4u. Retrying after 2 minutes.
# 파일 생성 완료: D:/Big Data Analysis/200 GAMES/BRONZE_IV_with_puuid.csv
# 처리 중: D:/Big Data Analysis/200 GAMES/BRONZE_II.csv
# Rate limit exceeded for Summoner ID: 0v8he9ob1bcDqYNah1ExcXntrhWYSBoVu7nJQFzF6WzuuFBU. Retrying after 2 minutes.
# 파일 생성 완료: D:/Big Data Analysis/200 GAMES/BRONZE_II_with_puuid.csv
# 처리 중: D:/Big Data Analysis/200 GAMES/BRONZE_III.csv
# Rate limit exceeded for Summoner ID: 1sTvhl4WnWDLbqz3oWoVYBE5VXa3B8ap8RyZ8dtXIW3v6jxw. Retrying after 2 minutes.
# 파일 생성 완료: D:/Big Data Analysis/200 GAMES/BRONZE_III_with_puuid.csv
# 처리 중: D:/Big Data Analysis/200 GAMES/EMERALD_III.csv
# Rate limit exceeded for Summoner ID: IfXLyMTxOeQ4QpsHUF5hclPVyzYomkRdqIInD4Xz-RNp56k. Retrying after 2 minutes.
# 파일 생성 완료: D:/Big Data Analysis/200 GAMES/EMERALD_III_with_puuid.csv
# 처리 중: D:/Big Data Analysis/200 GAMES
Retrying after 2 minutes.
# 파일 생성 완료: D:/Big Data Analysis/200 GAMES/GOLD_III_with_puuid.csv
# 처리 중: D:/Big Data Analysis/200 GAMES/PLATINUM_III.csv
# Rate limit exceeded for Summoner ID: WNN86wkz3_REcShMLywqxWYS3IKRB8WDHC6CxyVQgilKrW4. Retrying after 2 minutes.
# 파일 생성 완료: D:/Big Data Analysis/200 GAMES/PLATINUM_III_with_puuid.csv
# 처리 중: D:/Big Data Analysis/200 GAMES/EMERALD_IV.csv
# Rate limit exceeded for Summoner ID: 0YwKYRpZsMhpMa2aaD7WhC3Xo6BS8zNe0S_ts8HopyO-s7ZH. Retrying after 2 minutes.
# Rate limit exceeded for Summoner ID: x6Z5FccAkx5fceITDMReExoUOxsVdFeV2FfTA6yJzPJPpQ53. Retrying after 2 minutes.
# 파일 생성 완료: D:/Big Data Analysis/200 GAMES/EMERALD_IV_with_puuid.csv

# %%
# API 호출 제한을 위한 설정
base_url = "https://asia.api.riotgames.com"
max_retries = 5  # 최대 재시도 횟수
max_calls_per_2min = 100  # 2분당 최대 API 호출 수
max_calls_per_sec = 20  # 초당 최대 API 호출 수
call_count = 0  # 현재 호출 수 카운트
start_time = time.time()  # 타이머 시작

def get_match_ids(puuid):
    global call_count, start_time

    # API 호출 제한을 초과하지 않도록 조절
    call_count += 1
    elapsed_time = time.time() - start_time

    if call_count >= max_calls_per_2min:
        if elapsed_time < 120:
            print(f"2분 동안 {max_calls_per_2min}회 호출을 완료했습니다. 2분 동안 대기합니다.")
            time.sleep(120 - elapsed_time)
        call_count = 0
        start_time = time.time()

    url = f"{base_url}/lol/match/v5/matches/by-puuid/{puuid}/ids?start=0&count=20&api_key={api_key}"
    retries = 0
    while retries < max_retries:
        response = requests.get(url)
        if response.status_code == 200:
            match_ids = response.json()
            return match_ids
        elif response.status_code == 429:
            print(f"Rate limit exceeded for PUUID: {puuid}. Retrying after 2 minutes.")
            time.sleep(120)  # 2분 대기
        else:
            print(f"Error getting match IDs for PUUID: {puuid}: {response.status_code} - {response.text}")
            return None
        retries += 1
    print(f"Failed to get match IDs for PUUID: {puuid} after {max_retries} retries.")
    return None

def add_match_ids_to_csv(file_path):
    df = pd.read_csv(file_path, encoding='cp949')

    # matchid 열을 추가하기 위해 빈 리스트 생성
    expanded_rows = []

    for _, row in df.iterrows():
        puuid = row['puuid']
        match_ids = get_match_ids(puuid)

        if match_ids:
            for match_id in match_ids:
                new_row = row.copy()
                new_row['matchid'] = match_id
                expanded_rows.append(new_row)

        # 1초에 최대 20개 요청을 제한하기 위해 대기
        if call_count % max_calls_per_sec == 0:
            time.sleep(1)

    # 확장된 데이터프레임 생성
    expanded_df = pd.DataFrame(expanded_rows)

    # 결과를 새로운 CSV 파일로 저장
    output_file = file_path.replace('.csv', '_with_matchids.csv')
    expanded_df.to_csv(output_file, index=False, encoding='cp949')
    print(f"파일 생성 완료: {output_file}")

def process_all_csv_files(path):
    for filename in os.listdir(path):
        if filename.endswith('_with_puuid.csv') and not filename.endswith('_with_matchids.csv'):
            csv_file = os.path.join(path, filename)
            print(f"처리 중: {csv_file}")
            add_match_ids_to_csv(csv_file)

# 예시 실행
process_all_csv_files('/content/drive/MyDrive/롤 데이터 분석/meta_data')
# Out:
# 처리 중: /content/drive/MyDrive/롤 데이터 분석/meta_data
with_puuid_with_matchids.csv
# 처리 중: /content/drive/MyDrive/롤 데이터 분석/meta_data/BRONZE_I_with_puuid.csv
# Rate limit exceeded for PUUID: VfdWCkBE4c7f8r46qTrpp--DQkpZx9wtazzee6rS40uM3A70BjFKr03be9Ddc15XKQTeLPSB3tYUCg. Retrying after 2 minutes.
# 파일 생성 완료: /content/drive/MyDrive/롤 데이터 분석/meta_data/BRONZE_I_with_puuid_with_matchids.csv
# 처리 중: /content/drive/MyDrive/롤 데이터 분석/meta_data/BRONZE_II_with_puuid.csv
# Rate limit exceeded for PUUID: 2HTtbOcWqDtbcD-jq58wEhTmwj5XK61PQ1gPR-JxWwQ6w06OE8K-v9Ec2M5RZAJWZ6-jO8wY5KGEOA. Retrying after 2 minutes.
# 파일 생성 완료: /content/drive/MyDrive/롤 데이터 분석/meta_data/BRONZE_II_with_puuid_with_matchids.csv
# 처리 중: /content/drive/MyDrive/롤 데이터 분석/meta_data/SILVER_IV_with_puuid.csv
# Rate limit exceeded for PUUID: 5uPQDKeoXZNgv5M7QrXD9oJjBZ36zX9Zjrs7gCmUA_pG2xk3RpwGQ-GAETVuQf8o_q7Z2BZ3eDxZ1g. Retrying after 2 minutes.
# Rate limit exceeded for PUUID: UTP39oJj9QvZ9gaBgcKRO4n0mcxpFXRYq48N7KFekehUpptDBHT23ad__xrYikfqOYZ52ot9bWedJg. Retrying after 2 minutes.
# 파일 생성 완료: /content/drive/MyDrive/롤 데이터 분석/meta_data/SILVER_IV_with_puuid_with_matchids.csv

# %%
# API 호출 제한을 위한 설정
base_url = "https://asia.api.riotgames.com"
max_retries = 5  # 최대 재시도 횟수
max_calls_per_2min = 100  # 2분당 최대 API 호출 수
max_calls_per_sec = 20  # 초당 최대 API 호출 수
call_count = 0  # 현재 호출 수 카운트
start_time = time.time()  # 타이머 시작

def get_match_metadata(match_id):
    global call_count, start_time

    # API 호출 제한을 초과하지 않도록 조절
    call_count += 1
    elapsed_time = time.time() - start_time

    if call_count >= max_calls_per_2min:
        if elapsed_time < 120:
            print(f"2분 동안 {max_calls_per_2min}회 호출을 완료했습니다. 2분 동안 대기합니다.")
            time.sleep(120 - elapsed_time)
        call_count = 0
        start_time = time.time()

    url = f"{base_url}/lol/match/v5/matches/{match_id}?api_key={api_key}"
    retries = 0
    while retries < max_retries:
        response = requests.get(url)
        if response.status_code == 200:
            match_metadata = response.json()
            return match_metadata
        elif response.status_code == 429:
            print(f"Rate limit exceeded for match ID: {match_id}. Retrying after 2 minutes.")
            time.sleep(120)  # 2분 대기
        else:
            print(f"Error getting match metadata for match ID: {match_id}: {response.status_code} - {response.text}")
            return None
        retries += 1
    print(f"Failed to get match metadata for match ID: {match_id} after {max_retries} retries.")
    return None

def add_match_metadata_to_csv(file_path):
    df = pd.read_csv(file_path, encoding='cp949')

    # 새로운 열 추가를 위한 리스트
    expanded_rows = []

    for _, row in df.iterrows():
        match_id = row['matchid']
        match_metadata = get_match_metadata(match_id)

        if match_metadata:
            new_row = row.copy()

            # 원하는 메타데이터를 열로 추가 (여기서는 기본적인 예시로 gameDuration 추가)
            new_row['gameDuration'] = match_metadata.get('info', {}).get('gameDuration', None)
            new_row['gameVersion'] = match_metadata.get('info', {}).get('gameVersion', None)
            new_row['gameMode'] = match_metadata.get('info', {}).get('gameMode', None)

            expanded_rows.append(new_row)

        # 1초에 최대 20개 요청을 제한하기 위해 대기
        if call_count % max_calls_per_sec == 0:
            time.sleep(1)

    # 확장된 데이터프레임 생성
    expanded_df = pd.DataFrame(expanded_rows)

    # 결과를 새로운 CSV 파일로 저장
    output_file = file_path.replace('.csv', '_with_metadata.csv')
    expanded_df.to_csv(output_file, index=False, encoding='cp949')
    print(f"파일 생성 완료: {output_file}")

def process_all_csv_files(path):
    for filename in os.listdir(path):
        if filename.endswith('_with_matchids.csv') and not filename.endswith('_with_metadata.csv'):
            csv_file = os.path.join(path, filename)
            print(f"처리 중: {csv_file}")
            add_match_metadata_to_csv(csv_file)

# 예시 실행
process_all_csv_files('/content/drive/MyDrive/롤 데이터 분석/meta_data')
# Out:
# 처리 중: /content/drive/MyDrive/롤 데이터 분석/meta_data/SILVER_III_with_puuid_with_matchids.csv
# 2분 동안 100회 호출을 완료했습니다. 2분 동안 대기합니다.
# 2분 동안 100회 호출을 완료했습니다. 2분 동안 대기합니다.
# 2분 동안 100회 호출을 완료했습니다. 2분 동안 대기합니다.
# Rate limit exceeded for match ID: KR_7236274561. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7237252689. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7236818517. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7237519338. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7236598011. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7235583691. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7236131717. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7145266852. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7236799153. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7223656261. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7236953877. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7220387991. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7153625424. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7229477343. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7236103520. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7235944089. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7234291472. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7237496923. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7237019145. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7231640023. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7232483397. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7229601315. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7235734261. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7210020159. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7220699217. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7234053328. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7170163284. Retrying after 2 minutes.
# 파일 생성 완료: /content/drive/MyDrive/롤 데이터 분석/meta_data/SILVER_III_with_puuid_with_matchids_with_metadata.csv
# 처리 중: /content/drive/MyDrive/롤 데이터 분석/meta_data/SILVER_I_with_puuid_with_matchids.csv
# Rate limit exceeded for match ID: KR_7143086043. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7236809519. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7235543678. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7143671791. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7236274298. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7236292653. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7207471620. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7237447790. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7123263397. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7233853758. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7236963997. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7107054316. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7190389236. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7234840212. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7190081596. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7237146944. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7233709558. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7237186519. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7236691495. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7236596347. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7235159965. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7231004894. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7237272302. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7138056268. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7230853446. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7236707996. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7220108200. Retrying after 2 minutes.
# Error getting match metadata for match ID: KR_7220044574: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7214124477: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7214006793: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7211436778: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7211347394: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7210965517: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7210915773: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7210867966: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7209729807: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7209663650: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7209557051: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7209482094: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7209306452: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7209243234: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7209198246: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7209147569: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7208858766: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7236791579: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7236728698: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7236686122: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7235618839: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7235545239: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7235452981: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7235095722: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7232726180: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7232638702: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7232591091: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7232525966: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7232479965: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7231048626: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7230960026: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7230857954: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7230784761: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7230614307: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7230536660: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7230471270: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7230396351: 403 - {"status":{"message":"Forbidden","status_code":403}}
# 파일 생성 완료: /content/drive/MyDrive/롤 데이터 분석/meta_data/SILVER_I_with_puuid_with_matchids_with_metadata.csv
# 처리 중: /content/drive/MyDrive/롤 데이터 분석/meta_data/GOLD_IV_with_puuid_with_matchids.csv
# Error getting match metadata for match ID: KR_7175151314: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7175117384: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7175091940: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7174847490: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7173220279: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7171921190: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7171881599: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7171834654: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7167387742: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7167230912: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7167089215: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7166969773: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7166754945: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7150747787: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7150341547: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7150328198: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7150291446: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7150268439: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7150249155: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7150198844: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7226231812: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7225974353: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7225914791: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7225879487: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7218146523: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7218115508: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7218062791: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7217993816: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7217892830: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7217842134: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7214309608: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7214245616: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7210484692: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7202938089: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7198613164: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7198528913: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7198425390: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7196491755: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7196418935: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7194150050: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7236972603: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7236897568: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7236430936: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7236390879: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7234178832: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7234100744: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7234044247: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7233967987: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7233896826: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7233856620: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7232811980: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7232692244: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7232591357: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7232536494: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7230910968: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7230829370: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7230746749: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7230114352: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7228196362: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_7228157442: 403 - {"status":{"message":"Forbidden","status_code":403}}
# Error getting match metadata for match ID: KR_
}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-2b0d2b92d50d> in <cell line: 80>()
#      78
#      79 # 예시 실행
# ---> 80 process_all_csv_files('/content/drive/MyDrive/롤 데이터 분석/meta_data')
#
# <ipython-input-10-2b0d2b92d50d> in process_all_csv_files(path)
#      75             csv_file = os.path.join(path, filename)
#      76             print(f"처리 중: {csv_file}")
# ---> 77             add_match_metadata_to_csv(csv_file)
#      78
#      79 # 예시 실행
#
# <ipython-input-10-2b0d2b92d50d> in add_match_metadata_to_csv(file_path)
#      46     for _, row in df.iterrows():
#      47         match_id = row['matchid']
# ---> 48         match_metadata = get_match_metadata(match_id)
#      49
#      50         if match_metadata:
#
# <ipython-input-10-2b0d2b92d50d> in get_match_metadata(match_id)
#      24     retries = 0
#      25     while retries < max_retries:
# ---> 26         response = requests.get(url)
#      27         if response.status_code == 200:
#      28             match_metadata = response.json()
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     665
#     666         try:
# --> 667             resp = conn.urlopen(
#     668                 method=request.method,
#     669                 url=url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789
#     790             # Make the request on the HTTPConnection object
# --> 791             response = self._make_request(
#     792                 conn,
#     793                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535         # Receive the response from the server
#     536         try:
# --> 537             response = conn.getresponse()
#     538         except (BaseSSLError, OSError) as e:
#     539             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in getresponse(self)
#     459
#     460         # Get the response from http.client.HTTPConnection
# --> 461         httplib_response = super().getresponse()
#     462
#     463         try:
#
# /usr/lib/python3.10/http/client.py in getresponse(self)
#    1373         try:
#    1374             try:
# -> 1375                 response.begin()
#    1376             except ConnectionError:
#    1377                 self.close()
#
# /usr/lib/python3.10/http/client.py in begin(self)
#     316         # read until we get a non-100 response
#     317         while True:
# --> 318             version, status, reason = self._read_status()
#     319             if status != CONTINUE:
#     320                 break
#
# /usr/lib/python3.10/http/client.py in _read_status(self)
#     277
#     278     def _read_status(self):
# --> 279         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280         if len(line) > _MAXLINE:
#     281             raise LineTooLong("status line")
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# /usr/lib/python3.10/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1301                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1302                   self.__class__)
# -> 1303             return self.read(nbytes, buffer)
#    1304         else:
#    1305             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.10/ssl.py in read(self, len, buffer)
#    1157         try:
#    1158             if buffer is not None:
# -> 1159                 return self._sslobj.read(len, buffer)
#    1160             else:
#    1161                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import os
import time
import requests
import pandas as pd

# API 호출 제한을 위한 설정
base_url = "https://asia.api.riotgames.com"
max_retries = 5  # 최대 재시도 횟수
max_calls_per_2min = 100  # 2분당 최대 API 호출 수
max_calls_per_sec = 20  # 초당 최대 API 호출 수
call_count = 0  # 현재 호출 수 카운트
start_time = time.time()  # 타이머 시작
api_key = "YOUR_API_KEY"  # API 키를 여기에 입력

def get_match_metadata(match_id):
    global call_count, start_time

    # API 호출 제한을 초과하지 않도록 조절
    call_count += 1
    elapsed_time = time.time() - start_time

    if call_count >= max_calls_per_2min:
        if elapsed_time < 120:
            print(f"2분 동안 {max_calls_per_2min}회 호출을 완료했습니다. 2분 동안 대기합니다.")
            time.sleep(120 - elapsed_time)
        call_count = 0
        start_time = time.time()

    url = f"{base_url}/lol/match/v5/matches/{match_id}?api_key={api_key}"
    retries = 0
    while retries < max_retries:
        response = requests.get(url)
        if response.status_code == 200:
            match_metadata = response.json()
            return match_metadata
        elif response.status_code == 429:
            print(f"Rate limit exceeded for match ID: {match_id}. Retrying after 2 minutes.")
            time.sleep(120)  # 2분 대기
        else:
            print(f"Error getting match metadata for match ID: {match_id}: {response.status_code} - {response.text}")
            return None
        retries += 1
    print(f"Failed to get match metadata for match ID: {match_id} after {max_retries} retries.")
    return None

def add_match_metadata_to_csv(file_path):
    df = pd.read_csv(file_path, encoding='cp949')

    # 새로운 열 추가를 위한 리스트
    expanded_rows = []

    for _, row in df.iterrows():
        match_id = row['matchid']
        match_metadata = get_match_metadata(match_id)

        if match_metadata:
            new_row = row.copy()

            # 메타데이터 전체를 JSON 형식의 문자열로 추가
            new_row['metadata_json'] = json.dumps(match_metadata)

            expanded_rows.append(new_row)

        # 1초에 최대 20개 요청을 제한하기 위해 대기
        if call_count % max_calls_per_sec == 0:
            time.sleep(1)

    # 확장된 데이터프레임 생성
    expanded_df = pd.DataFrame(expanded_rows)

    # 결과를 새로운 CSV 파일로 저장
    output_file = file_path.replace('.csv', '_with_metadata.csv')
    expanded_df.to_csv(output_file, index=False, encoding='cp949')
    print(f"파일 생성 완료: {output_file}")

def process_all_csv_files(path):
    for filename in os.listdir(path):
        if filename.endswith('_with_matchids.csv') and not filename.endswith('_with_metadata.csv'):
            csv_file = os.path.join(path, filename)
            print(f"처리 중: {csv_file}")
            add_match_metadata_to_csv(csv_file)

# 예시 실행
process_all_csv_files('/content/drive/MyDrive/롤 데이터 분석/meta_data')

# %%
# API 호출 제한을 위한 설정
base_url = "https://asia.api.riotgames.com"
max_retries = 5  # 최대 재시도 횟수
max_calls_per_2min = 100  # 2분당 최대 API 호출 수
max_calls_per_sec = 20  # 초당 최대 API 호출 수
call_count = 0  # 현재 호출 수 카운트
start_time = time.time()  # 타이머 시작

def get_match_metadata(match_id):
    global call_count, start_time

    # API 호출 제한을 초과하지 않도록 조절
    call_count += 1
    elapsed_time = time.time() - start_time

    if call_count >= max_calls_per_2min:
        if elapsed_time < 120:
            print(f"2분 동안 {max_calls_per_2min}회 호출을 완료했습니다. 2분 동안 대기합니다.")
            time.sleep(120 - elapsed_time)
        call_count = 0
        start_time = time.time()

    url = f"{base_url}/lol/match/v5/matches/{match_id}?api_key={api_key}"
    retries = 0
    while retries < max_retries:
        response = requests.get(url)
        if response.status_code == 200:
            match_metadata = response.json()
            return match_metadata
        elif response.status_code == 429:
            print(f"Rate limit exceeded for match ID: {match_id}. Retrying after 2 minutes.")
            time.sleep(120)  # 2분 대기
        else:
            print(f"Error getting match metadata for match ID: {match_id}: {response.status_code} - {response.text}")
            return None
        retries += 1
    print(f"Failed to get match metadata for match ID: {match_id} after {max_retries} retries.")
    return None

def add_match_metadata_to_csv(file_path):
    df = pd.read_csv(file_path, encoding='cp949')

    # 새로운 열 추가를 위한 리스트
    expanded_rows = []

    for _, row in df.iterrows():
        match_id = row['matchid']
        match_metadata = get_match_metadata(match_id)

        if match_metadata:
            new_row = row.copy()

            # 메타데이터 전체를 JSON 형식의 문자열로 추가
            new_row['metadata_json'] = json.dumps(match_metadata)

            expanded_rows.append(new_row)

        # 1초에 최대 20개 요청을 제한하기 위해 대기
        if call_count % max_calls_per_sec == 0:
            time.sleep(1)

    # 확장된 데이터프레임 생성
    expanded_df = pd.DataFrame(expanded_rows)

    # 결과를 새로운 CSV 파일로 저장
    output_file = file_path.replace('.csv', '_with_metadata.csv')
    expanded_df.to_csv(output_file, index=False, encoding='cp949')
    print(f"파일 생성 완료: {output_file}")

# 파일 경로 설정
csv_file = '/content/drive/MyDrive/롤 데이터 분석/meta_data/DIAMOND_I_with_puuid_with_matchids.csv'

# 매치 메타데이터를 추가한 CSV 파일 생성
add_match_metadata_to_csv(csv_file)
# Out:
# 2분 동안 100회 호출을 완료했습니다. 2분 동안 대기합니다.
# 2분 동안 100회 호출을 완료했습니다. 2분 동안 대기합니다.
# Rate limit exceeded for match ID: KR_7186894425. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7119027002. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7144276667. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7218622415. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7155917788. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7229284422. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7098131566. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7232724000. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7224697333. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7125298752. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7236073787. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7145481975. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7216157355. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7147050557. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7124393958. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7135530040. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7234954958. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7141973769. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7232732283. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7189921606. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7142107898. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7231281783. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7133552787. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7196582244. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7205956633. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7232058076. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7212432654. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7149593790. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7232500882. Retrying after 2 minutes.
# Rate limit exceeded for match ID: KR_7219566767. Retrying after 2 minutes.
# 파일 생성 완료: /content/drive/MyDrive/롤 데이터 분석/meta_data/DIAMOND_I_with_puuid_with_matchids_with_metadata.csv
